# %% [markdown]
# ### Attribute and methods made the object
# ### Attrribute == variable
# ### Methods == functions that a object can do
# ### Trying to model the real life object - object(data+functionality)
# ### Multiple version of a object can be generated in a object -> from a blueprint of the object and total is called class
# ### Blueprint -> class , object - real life entity
# ### class -> blueprint of the object
