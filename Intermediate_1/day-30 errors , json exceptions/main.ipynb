# %%
try:
    file =  open('a_file.txt')
    a_dictionary  = {'key' : 'value'}
    print(a_dictionary['key'])
except FileNotFoundError:
    # print("File not found")
    file = open("a_file" , 'w') 
    file.write("Kuch to garbad hai daya ")
except KeyError as error_message:
    print(f"Error: {error_message}")  # Print the error message
else:
     content = file.read()
     print(content)  # Print the content of the file
finally:
    file.close()  # Close the file
    print("File was close ! ")
# Out:
# File was close !

# %%
height = int (input())
weight  = int (input())

if height >3:
    raise ValueError("You are not in the range of human height ")
bmi = weight / height **2
print(bmi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       2 weight  = int (input())
#       4 if height >3:
# ----> 5     raise ValueError("You are not in the range of human height ")
#       6 bmi = weight / height **2
#       7 print(bmi)
#
# ValueError: You are not in the range of human height

# %%
fruits = ["Apple", "Pear", "Orange"]

# Catch the exception and make sure the code runs without crashing.
def make_pie(index):
    try :   
        fruit = fruits[index]
        print(fruit + " pie")
    except:
        print("Fruit pie")
        
def create_pie(index):
    try :
        fruit = fruits[index]
    except IndexError:
        print('fruit Pie ')
    else:
        print(fruit + " pie")
        
make_pie(4)
create_pie(2)
# Out:
# Fruit pie
# Orange pie

# %%
facebook_posts = [
    {'Likes': 21, 'Comments': 2},
    {'Likes': 13, 'Comments': 2, 'Shares': 1},
    {'Likes': 33, 'Comments': 8, 'Shares': 3},
    {'Likes': 343, 'Comments': 8, 'Shares': 3},
    {'Likes': 343, 'Comments': 8, 'Shares': 3},
    {'Likes': 334, 'Comments': 8, 'Shares': 3},
    {'Likes': 33, 'Comments': 8, 'Shares': 3},
    {'Likes': 0, 'Comments': 8, 'Shares': 3},
    {'Likes': 33, 'Comments': 8, 'Shares': 3},
    {'Comments': 4, 'Shares': 2},
    {'Comments': 1, 'Shares': 1},
    {'Likes': 19, 'Comments': 3}
]

def count_likes(posts):
    total_likes = 0
    for post in posts:
        try:
            total_likes += post['Likes']
        except KeyError:
            # If 'Likes' key is missing, skip this post
            pass
    return total_likes

print(count_likes(facebook_posts))
# Out:
# 1172
