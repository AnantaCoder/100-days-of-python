# %% [markdown]
# # Python Loops

# %%
fruita = ["apple" , "banana" , "strawberry"]

for i in fruita:
    print(i)
# Out:
# apple
# banana
# strawberry

# %%
fruta = ["apple", "banana", "strawberry"]

for i in fruta:
    print(i)
    print(i + " ,KELA")
    if i == "banana":
        break
# Out:
# apple
# apple ,KELA
# banana
# banana ,KELA

# %% [markdown]
# # Exam Result Calculator

# %%
student_marks = [57, 23, 89, 74, 16, 65, 38, 51, 70, 21, 82, 93, 18, 46, 77, 49, 91, 37, 85, 28,
33, 12, 67, 94, 26, 56, 61, 43, 78, 83, 19, 29, 40, 75, 58, 64, 34, 53, 90, 88,
20, 62, 32, 27, 72, 55, 97, 87, 13, 39, 60, 31, 84, 66, 41, 99, 14, 45, 22, 81,
7, 52, 92, 50, 35, 76, 68, 11, 47, 25, 73, 63, 42, 54, 96, 15, 86, 30, 24, 80,
98, 36, 79, 48, 59, 71, 95, 44, 100, 69, 10, 48, 22, 58, 85, 47, 12, 93, 20, 37]
sum = 0
for i in student_marks:
    sum += i
    
number_of_students = len(student_marks)

average = (sum/number_of_students) 

print(f"The avarage persentise of the students is {average}")

max_score = 0

for i in student_marks:
    if i > max_score:
        max_score = i
  
max_score_index = student_marks.index(max_score)   #TO GET THE INEDX OF THE DESIGNATED NUMBER   
print(f"The sudent with the maximum number is :- {max_score} with index of number:-  {max_score_index}")
# Out:
# The avarage persentise of the students is 54.17
# The sudent with the maximum number is :- 100 with index of number:-  88

# %% [markdown]
# # Range

# %% [markdown]
# # Sum of All nubers from 1 to 100

# %%
numneric_list = [0]
for i in range(1,101):
    numneric_list.append(i)


sum = 0 
for i in numneric_list:
    sum += i
    
print(sum)
# Out:
# 5050

# %%
#Alternate
total = 0 
for i in range(1, 101):
    total += i
print(total)
# Out:
# 5050
