# %% [markdown]
# input  function and concatinate

# %%
print("hellow " + input("what is your name?"))
# Out:
# hellow bfvd

# %%
numofletter = len("gn sdajsdjahbfhbejr")
print(numofletter)
# Out:
# 19

# %%
print("Hellow and welcome to Band name generator")

print(" What is the city u grew up in?")
city = input()
print("What is the name of the pet u had in childhood?")
pet = input()

print("Your band name is :"+ city +" "+ pet +"\n")
# Out:
# Hellow and welcome to Band name generator
#  What is the city u grew up in?
# What is the name of the pet u had in childhood?
# Your band name is :jk jncf\\\
