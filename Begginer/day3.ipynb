# %% [markdown]
# ## if ilse loops , coinditionals

# %%
wahter_level = int(input("enter the level in m :"))
if wahter_level <99:
    print("water level is low")
else:
    print("water level is high")
# Out:
# water level is low

# %%
print("welcomne to  the rolercoster")
height = int(input("Thell me your height (cm): " ))
bill = 0
if height >= 120:
    print("you can ride the rolercoster")
    age = int(input("Tell me your age u shawty? "))
    if age <= 5:
        print("you are too young to ride the rolercoster")
    elif age <= 6:
        bill = 50
        print("your bill is " , bill)
    elif age <= 13:
        bill = 75
        print("your bill is", bill)
    elif age>= 45 and age <= 55:
        print("Dont worry Have a free rise on us!!!")
    else:
        bill = 100
        print("your bill is", bill)

else:
    print("you can't ride the rolercoster")

wantsfoto = input("Do you wants a photo of your ride with dickky!? Y or N.")
if wantsfoto =="Y":
    bill += 20

print(f"Your finall bill is {bill}")
# Out:
# welcomne to  the rolercoster
# you can ride the rolercoster
# Dont worry Have a free rise on us!!!
# Your finall bill is 0

# %% [markdown]
# # Operators

# %%
a = 10
# a < 10 or  a>20
a < 10 and  a>20
# Out:
# False

# %%
not 5 ==5
# Out:
# False

# %%
False or False or True
# Out:
# True

# %%
a = 5
b = 7
if a >= b and a != b:
    print("a is greater than or equal to b")
elif not a >+ b and a!= b:
    print("B")
else:
    print("C")
# Out:
# B

# %%
x = 5
y = 3

print(x != y)

# returns True because 5 is not equal to 3
# Out:
# True

# %%
x = 5
y = 3

print(not x == y)

# returns false because 5 is not equal to 3
# Out:
# True

# %%
x = 5
y = 3

print(not x != y)

# returns false because 5 is not equal to 3
# Out:
# False
