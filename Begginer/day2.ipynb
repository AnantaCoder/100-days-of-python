# %% [markdown]
# ## DATA TYPES , Number maniplation  , f-string

# %%
print("hellow"[2])
# Out:
# l

# %%
print("lala" + "land") #string concatination
print("544" + "156")
print(12 + 12)
# Out:
# lalaland
# 544156
# 24

# %%
a = 3.14 # float
print(a)
#boolean 
True and False
# Out:
# 3.14

# %%
name = len(input("What is your name ?"))
print(name)
print(type(name)) #intiger
new= str(name)
print(new) #string
# Out:
# 2
# <class 'int'>
# 2

# %%
a = float(1546854654)
print(type(a))
# Out:
# <class 'float'>

# %%
# type of data\
print(2 ** 4)
print(pow(2,4))
# Out:
# 16
# 16

# %% [markdown]
# PEMDAS  ALAWYS LEFT TO RIGHT\
# () \
# ** \
# */ \
# +-

# %%
round(46464.534654)
# Out:
# 46465

# %%
# f string its easy the format
score = 0
height = 41
print(f"your score is {score}")
# Out:
# your score is 0
