# %% [markdown]
# # Bugs and errors

# %%
from random import randint
dice = ["1","2","3","4","5","6"]
diceNum = randint(0 , len(dice)-1)
print(dice[diceNum])
# Out:
# 4

# %%
dob = int(input("Enter yu=our year of birth"))
if dob >= 2010:
    print("You are a gen alpha ")
elif dob <= 1900:
    print("You are a gen ghoul ")
else:
    print("u are gonna be dea d soon")
# Out:
# You are a gen ghoul

# %%
def func(number):
    if number %2== 0:
        print("Even")
    else:
        print("Odd")
        
func(1)
# Out:
# Odd

# %%
import random 
import math


b = []
a = [1,2,3,4,5,6,7,8,9]

new_item = 0
for i in range(len(a)):
    new_item = random.choice(a) #to  get a new item 
    new = pow(new_item,2)
    b.append(new)
print(b)
# Out:
# [25, 64, 4, 81, 25, 16, 4, 16, 49]
