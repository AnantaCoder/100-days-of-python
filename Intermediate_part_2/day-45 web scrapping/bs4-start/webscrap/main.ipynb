# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://news.ycombinator.com/news')
Y_combi = response.text

soup = BeautifulSoup(Y_combi,'html.parser')
print(soup.title.string)
# Find and print the first news story link (we look for 'a' tags under 'titleline' or similar classes)
first_title = soup.find('span', class_='titleline').find('a')
# print(first_title.text)  # Print the text of the first story link
# print(first_title['href'])  

first_score = soup.find('span',class_='score')
first_score_all = soup.find_all('span',class_='score')
# print(first_score.string.split()[0])
score_value = [int(score.string.split()[0]) for score in first_score_all ]
if score_value:  # Ensure there are scores to compare
    highest_score = max(score_value)
    print("The highest score is:", highest_score)
else:
    print("No scores found.")
# Out:
# Hacker News
# The highest score is: 411

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
response = requests.get('https://news.ycombinator.com/news')
Y_combi = response.text

# Parse the HTML
soup = BeautifulSoup(Y_combi, 'html.parser')

# Find all the scores
scores = soup.find_all('span', class_='score')

# Extract and convert score text to integers
score_values = [int(score.string.split()[0]) for score in scores]
print(score_value)
# Find the highest score
if score_values:  # Ensure there are scores to compare
    highest_score = max(score_values)
    print("The highest score is:", highest_score)
else:
    print("No scores found.")
# Out:
# [129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129]
# The highest score is: 407
